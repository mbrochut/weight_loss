# %% [markdown]
# # Statistical Analysis
# ## Import packages and load data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from scipy.stats import chisquare
import ast

# %%
df = pd.read_excel("./data/df_for_analysis.xlsx",index_col=0)

# %% [markdown]
# ## General information

# %%
start_date = datetime(2013,1,1)
end_date = datetime.now()

#Select data between two dates
mask_date = (df['Date'] > start_date) & (df['Date'] <= end_date)
df = df.loc[mask_date]

# %%
df
# Out:
#         Mouse_ID ID_Experiment        Cage     Strain       Date  \
# 0      TRO-05432        ID_001           A  BALB/cByJ 2014-06-05
# 1      TRO-05433        ID_001           A  BALB/cByJ 2014-06-05
# 2      TRO-05434        ID_001           A  BALB/cByJ 2014-06-05
# 3      TRO-05435        ID_001           A  BALB/cByJ 2014-06-05
# 4      TRO-05456        ID_001           B  BALB/cByJ 2014-06-05
# ...          ...           ...         ...        ...        ...
# 2352  TRO-028337        ID_096  ETRO-01911   C57BL/6J 2023-03-03
# 2353  TRO-028338        ID_096  ETRO-01911   C57BL/6J 2023-03-03
# 2354  TRO-028339        ID_096  ETRO-01911   C57BL/6J 2023-03-03
# 2355  TRO-028342        ID_096  ETRO-01911   C57BL/6J 2023-03-03
# 2356  TRO-028343        ID_096  ETRO-01911   C57BL/6J 2023-03-03
#
#                                       Experiment Group           Group_info  \
# 0                             Candida/Propionate    1A  Propionate / 2*10^5
# 1                             Candida/Propionate    1A  Propionate / 2*10^5
# 2                             Candida/Propionate    1A  Propionate / 2*10^5
# 3                             Candida/Propionate    1A  Propionate / 2*10^5
# 4                             Candida/Propionate    1A  Propionate / 2*10^5
# ...                                          ...   ...                  ...
# 2352  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
# 2353  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
# 2354  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
# 2355  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
# 2356  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
#
#      H0             Pre_traitment  ... survival_0.07 time_0.06 survival_0.06  \
# 0     1                propionate  ...             1       1.5             1
# 1     1                propionate  ...             1       1.5             1
# 2     1                propionate  ...             1       2.5             1
# 3     1                propionate  ...             1       1.5             1
# 4     1                propionate  ...             1       1.5             1
# ...  ..                       ...  ...           ...       ...           ...
# 2352  1  training/cross-fostering  ...             1       1.5             1
# 2353  1  training/cross-fostering  ...             1       2.5             1
# 2354  1  training/cross-fostering  ...             1       5.5             1
# 2355  1  training/cross-fostering  ...             0       8.0             0
# 2356  1  training/cross-fostering  ...             1       2.5             1
#
#      time_0.05 survival_0.05 time_original  survival_original  \
# 0          1.5             1           9.0                  1
# 1          1.5             1           9.0                  1
# 2          2.5             1           9.0                  1
# 3          1.5             1           6.0                  1
# 4          1.5             1           7.0                  1
# ...        ...           ...           ...                ...
# 2352       1.5             1           5.0                  1
# 2353       2.5             1           4.0                  1
# 2354       5.5             1           6.0                  1
# 2355       8.0             0           8.0                  0
# 2356       2.5             1           5.0                  1
#
#       max_loss_weight_percentage exp sub_exp
# 0                       0.629181   1       A
# 1                       0.660748   1       A
# 2                       0.639184   1       A
# 3                       0.664051   1       A
# 4                       0.707420   1       A
# ...                          ...  ..     ...
# 2352                    0.761733   3      no
# 2353                    0.865900   3      no
# 2354                    0.926829   3      no
# 2355                    0.996350   3      no
# 2356                    0.889706   3      no
#
# [2357 rows x 88 columns]

# %%
#change name of dead and alive for result formatting
df['survival_original'] = df['survival_original'].replace({1:'Dead',0:'Alive'})

# %%
#RESULT: N_Experiment; N_Mice
group_by_infection = df.groupby(['Infection'])
n_unique = group_by_infection.nunique()
n_unique_infos = n_unique.loc[:,:'ID_Experiment']
n_unique_infos = n_unique_infos.rename(columns={'ID_Experiment':'N_Experiment','Mouse_ID':'N_Mice'})

#RESULT: Alive; Dead; Alive_in_%
dead_alive = group_by_infection['survival_original'].value_counts().sort_index(ascending=False).unstack()

# %%
result = pd.concat([n_unique_infos,dead_alive],axis=1)
result
# Out:
#                N_Mice  N_Experiment  Alive  Dead
# Infection
# C. albicans       252             6    164    88
# H1N1              336            19    203   133
# Listeria         1048            39    555   493
# S. pneumoniae     721            32    328   393

# %%
# Create a dictionary with the sum of each column
total_sum = result.sum()

# Create a DataFrame from the sum with the index name 'Total'
total_df = pd.DataFrame(total_sum).T
total_df.index = ['Total']
total_df.index.name = 'Infection'
total_df
# Out:
#            N_Mice  N_Experiment  Alive  Dead
# Infection
# Total        2357            96   1250  1107

# %%
general_info = pd.concat([result,total_df],axis=0)

# %%
general_info['mortality'] = round(general_info['Dead']/(general_info['Alive']+general_info['Dead'])*100,1)
general_info
# Out:
#                N_Mice  N_Experiment  Alive  Dead  mortality
# Infection
# C. albicans       252             6    164    88       34.9
# H1N1              336            19    203   133       39.6
# Listeria         1048            39    555   493       47.0
# S. pneumoniae     721            32    328   393       54.5
# Total            2357            96   1250  1107       47.0

# %% [markdown]
# ## Survival percentage

# %%
data = df.loc[:,['Infection','survival_original','survival_0.3','survival_0.25','survival_0.2','survival_0.15','survival_0.1']]
data = data.replace({0:'Alive',1:'Dead'})
data
# Out:
#           Infection survival_original survival_0.3 survival_0.25 survival_0.2  \
# 0       C. albicans              Dead         Dead          Dead         Dead
# 1       C. albicans              Dead         Dead          Dead         Dead
# 2       C. albicans              Dead         Dead          Dead         Dead
# 3       C. albicans              Dead         Dead          Dead         Dead
# 4       C. albicans              Dead         Dead          Dead         Dead
# ...             ...               ...          ...           ...          ...
# 2352  S. pneumoniae              Dead         Dead          Dead         Dead
# 2353  S. pneumoniae              Dead         Dead          Dead         Dead
# 2354  S. pneumoniae              Dead         Dead          Dead         Dead
# 2355  S. pneumoniae             Alive        Alive         Alive        Alive
# 2356  S. pneumoniae              Dead         Dead          Dead         Dead
#
#      survival_0.15 survival_0.1
# 0             Dead         Dead
# 1             Dead         Dead
# 2             Dead         Dead
# 3             Dead         Dead
# 4             Dead         Dead
# ...            ...          ...
# 2352          Dead         Dead
# 2353          Dead         Dead
# 2354          Dead         Dead
# 2355         Alive        Alive
# 2356          Dead         Dead
#
# [2357 rows x 7 columns]

# %%
survival = data.melt(id_vars=["Infection"],value_name="survival",var_name="threshold")
survival = survival.groupby('Infection').value_counts().reset_index().rename(columns={0:"number_of_mice"})
survival
# Out:
#         Infection          threshold survival  number_of_mice
# 0     C. albicans       survival_0.1     Dead             220
# 1     C. albicans      survival_0.15     Dead             187
# 2     C. albicans  survival_original    Alive             164
# 3     C. albicans       survival_0.2     Dead             149
# 4     C. albicans       survival_0.3    Alive             148
# 5     C. albicans      survival_0.25    Alive             131
# 6     C. albicans      survival_0.25     Dead             121
# 7     C. albicans       survival_0.3     Dead             104
# 8     C. albicans       survival_0.2    Alive             103
# 9     C. albicans  survival_original     Dead              88
# 10    C. albicans      survival_0.15    Alive              65
# 11    C. albicans       survival_0.1    Alive              32
# 12           H1N1       survival_0.1     Dead             283
# 13           H1N1      survival_0.15     Dead             249
# 14           H1N1       survival_0.2     Dead             209
# 15           H1N1  survival_original    Alive             203
# 16           H1N1       survival_0.3    Alive             186
# 17           H1N1      survival_0.25     Dead             178
# 18           H1N1      survival_0.25    Alive             158
# 19           H1N1       survival_0.3     Dead             150
# 20           H1N1  survival_original     Dead             133
# 21           H1N1       survival_0.2    Alive             127
# 22           H1N1      survival_0.15    Alive              87
# 23           H1N1       survival_0.1    Alive              53
# 24       Listeria       survival_0.1     Dead             776
# 25       Listeria      survival_0.15     Dead             677
# 26       Listeria       survival_0.2     Dead             572
# 27       Listeria  survival_original    Alive             555
# 28       Listeria       survival_0.3    Alive             550
# 29       Listeria      survival_0.25    Alive             530
# 30       Listeria      survival_0.25     Dead             518
# 31       Listeria       survival_0.3     Dead             498
# 32       Listeria  survival_original     Dead             493
# 33       Listeria       survival_0.2    Alive             476
# 34       Listeria      survival_0.15    Alive             371
# 35       Listeria       survival_0.1    Alive             272
# 36  S. pneumoniae       survival_0.1     Dead             446
# 37  S. pneumoniae      survival_0.15     Dead             415
# 38  S. pneumoniae       survival_0.2     Dead             403
# 39  S. pneumoniae      survival_0.25     Dead             397
# 40  S. pneumoniae       survival_0.3     Dead             394
# 41  S. pneumoniae  survival_original     Dead             393
# 42  S. pneumoniae  survival_original    Alive             328
# 43  S. pneumoniae       survival_0.3    Alive             327
# 44  S. pneumoniae      survival_0.25    Alive             324
# 45  S. pneumoniae       survival_0.2    Alive             318
# 46  S. pneumoniae      survival_0.15    Alive             306
# 47  S. pneumoniae       survival_0.1    Alive             275

# %%
# Pivot the table to have 'Infection' as columns and calculate the ratio
statistics = survival.pivot(index=['Infection',"threshold"], columns='survival', values='number_of_mice')
statistics['Ratio'] = statistics['Dead'] / (statistics['Dead'] + statistics['Alive'])
statistics = statistics.reset_index(level=1)
statistics['supplementary_death'] = statistics.groupby('Infection').apply(lambda x: x['Dead'] - x[x['threshold']=="survival_original"]['Dead']).values
statistics = statistics.reset_index()
statistics
# Out:
# survival      Infection          threshold  Alive  Dead     Ratio  \
# 0           C. albicans       survival_0.1     32   220  0.873016
# 1           C. albicans      survival_0.15     65   187  0.742063
# 2           C. albicans       survival_0.2    103   149  0.591270
# 3           C. albicans      survival_0.25    131   121  0.480159
# 4           C. albicans       survival_0.3    148   104  0.412698
# 5           C. albicans  survival_original    164    88  0.349206
# 6                  H1N1       survival_0.1     53   283  0.842262
# 7                  H1N1      survival_0.15     87   249  0.741071
# 8                  H1N1       survival_0.2    127   209  0.622024
# 9                  H1N1      survival_0.25    158   178  0.529762
# 10                 H1N1       survival_0.3    186   150  0.446429
# 11                 H1N1  survival_original    203   133  0.395833
# 12             Listeria       survival_0.1    272   776  0.740458
# 13             Listeria      survival_0.15    371   677  0.645992
# 14             Listeria       survival_0.2    476   572  0.545802
# 15             Listeria      survival_0.25    530   518  0.494275
# 16             Listeria       survival_0.3    550   498  0.475191
# 17             Listeria  survival_original    555   493  0.470420
# 18        S. pneumoniae       survival_0.1    275   446  0.618585
# 19        S. pneumoniae      survival_0.15    306   415  0.575589
# 20        S. pneumoniae       survival_0.2    318   403  0.558946
# 21        S. pneumoniae      survival_0.25    324   397  0.550624
# 22        S. pneumoniae       survival_0.3    327   394  0.546463
# 23        S. pneumoniae  survival_original    328   393  0.545076
#
# survival  supplementary_death
# 0                         132
# 1                          99
# 2                          61
# 3                          33
# 4                          16
# 5                           0
# 6                         150
# 7                         116
# 8                          76
# 9                          45
# 10                         17
# 11                          0
# 12                        283
# 13                        184
# 14                         79
# 15                         25
# 16                          5
# 17                          0
# 18                         53
# 19                         22
# 20                         10
# 21                          4
# 22                          1
# 23                          0

# %% [markdown]
# ## Chi2 tests

# %%
def chi_square_in_lambda_function(x):
    observed = x[x['threshold']=='survival_original'][['Dead','Alive']].values.tolist()[0]
    result = []
    for index, rows in x.iterrows():
        data = rows[['Dead','Alive']]
        chi2, p = chisquare(observed,data)
        result += [p]
    x.index
    return pd.Series(result,x.index.values)

# %%
chi_result = statistics.groupby("Infection").apply(lambda x: chi_square_in_lambda_function(x))
statistics["chi2"] = chi_result.values
statistics
# Out:
# survival      Infection          threshold  Alive  Dead     Ratio  \
# 0           C. albicans       survival_0.1     32   220  0.873016
# 1           C. albicans      survival_0.15     65   187  0.742063
# 2           C. albicans       survival_0.2    103   149  0.591270
# 3           C. albicans      survival_0.25    131   121  0.480159
# 4           C. albicans       survival_0.3    148   104  0.412698
# 5           C. albicans  survival_original    164    88  0.349206
# 6                  H1N1       survival_0.1     53   283  0.842262
# 7                  H1N1      survival_0.15     87   249  0.741071
# 8                  H1N1       survival_0.2    127   209  0.622024
# 9                  H1N1      survival_0.25    158   178  0.529762
# 10                 H1N1       survival_0.3    186   150  0.446429
# 11                 H1N1  survival_original    203   133  0.395833
# 12             Listeria       survival_0.1    272   776  0.740458
# 13             Listeria      survival_0.15    371   677  0.645992
# 14             Listeria       survival_0.2    476   572  0.545802
# 15             Listeria      survival_0.25    530   518  0.494275
# 16             Listeria       survival_0.3    550   498  0.475191
# 17             Listeria  survival_original    555   493  0.470420
# 18        S. pneumoniae       survival_0.1    275   446  0.618585
# 19        S. pneumoniae      survival_0.15    306   415  0.575589
# 20        S. pneumoniae       survival_0.2    318   403  0.558946
# 21        S. pneumoniae      survival_0.25    324   397  0.550624
# 22        S. pneumoniae       survival_0.3    327   394  0.546463
# 23        S. pneumoniae  survival_original    328   393  0.545076
#
# survival  supplementary_death           chi2
# 0                         132  1.172261e-137
# 1                          99   4.191188e-46
# 2                          61   5.426556e-15
# 3                          33   3.170145e-05
# 4                          16   4.063269e-02
# 5                           0   1.000000e+00
# 6                         150  1.259931e-111
# 7                         116   2.630289e-47
# 8                          76   1.222074e-17
# 9                          45   8.715478e-07
# 10                         17   6.209860e-02
# 11                          0   1.000000e+00
# 12                        283   1.786476e-88
# 13                        184   1.408030e-32
# 14                         79   9.523214e-07
# 15                         25   1.224415e-01
# 16                          5   7.571070e-01
# 17                          0   1.000000e+00
# 18                         53   4.832398e-05
# 19                         22   9.737833e-02
# 20                         10   4.532128e-01
# 21                          4   7.645780e-01
# 22                          1   9.403678e-01
# 23                          0   1.000000e+00

# %% [markdown]
# ### rearange the dataframe

# %%
statistics.pivot_table(values=["Alive","Dead","Ratio","supplementary_death","chi2"],index=["threshold","Infection"])
# Out:
# survival                         Alive  Dead     Ratio           chi2  \
# threshold         Infection
# survival_0.1      C. albicans       32   220  0.873016  1.172261e-137
#                   H1N1              53   283  0.842262  1.259931e-111
#                   Listeria         272   776  0.740458   1.786476e-88
#                   S. pneumoniae    275   446  0.618585   4.832398e-05
# survival_0.15     C. albicans       65   187  0.742063   4.191188e-46
#                   H1N1              87   249  0.741071   2.630289e-47
#                   Listeria         371   677  0.645992   1.408030e-32
#                   S. pneumoniae    306   415  0.575589   9.737833e-02
# survival_0.2      C. albicans      103   149  0.591270   5.426556e-15
#                   H1N1             127   209  0.622024   1.222074e-17
#                   Listeria         476   572  0.545802   9.523214e-07
#                   S. pneumoniae    318   403  0.558946   4.532128e-01
# survival_0.25     C. albicans      131   121  0.480159   3.170145e-05
#                   H1N1             158   178  0.529762   8.715478e-07
#                   Listeria         530   518  0.494275   1.224415e-01
#                   S. pneumoniae    324   397  0.550624   7.645780e-01
# survival_0.3      C. albicans      148   104  0.412698   4.063269e-02
#                   H1N1             186   150  0.446429   6.209860e-02
#                   Listeria         550   498  0.475191   7.571070e-01
#                   S. pneumoniae    327   394  0.546463   9.403678e-01
# survival_original C. albicans      164    88  0.349206   1.000000e+00
#                   H1N1             203   133  0.395833   1.000000e+00
#                   Listeria         555   493  0.470420   1.000000e+00
#                   S. pneumoniae    328   393  0.545076   1.000000e+00
#
# survival                         supplementary_death
# threshold         Infection
# survival_0.1      C. albicans                    132
#                   H1N1                           150
#                   Listeria                       283
#                   S. pneumoniae                   53
# survival_0.15     C. albicans                     99
#                   H1N1                           116
#                   Listeria                       184
#                   S. pneumoniae                   22
# survival_0.2      C. albicans                     61
#                   H1N1                            76
#                   Listeria                        79
#                   S. pneumoniae                   10
# survival_0.25     C. albicans                     33
#                   H1N1                            45
#                   Listeria                        25
#                   S. pneumoniae                    4
# survival_0.3      C. albicans                     16
#                   H1N1                            17
#                   Listeria                         5
#                   S. pneumoniae                    1
# survival_original C. albicans                      0
#                   H1N1                             0
#                   Listeria                         0
#                   S. pneumoniae                    0

# %% [markdown]
# ## Mice under 30% THR

# %%
df
# Out:
#         Mouse_ID ID_Experiment        Cage     Strain       Date  \
# 0      TRO-05432        ID_001           A  BALB/cByJ 2014-06-05
# 1      TRO-05433        ID_001           A  BALB/cByJ 2014-06-05
# 2      TRO-05434        ID_001           A  BALB/cByJ 2014-06-05
# 3      TRO-05435        ID_001           A  BALB/cByJ 2014-06-05
# 4      TRO-05456        ID_001           B  BALB/cByJ 2014-06-05
# ...          ...           ...         ...        ...        ...
# 2352  TRO-028337        ID_096  ETRO-01911   C57BL/6J 2023-03-03
# 2353  TRO-028338        ID_096  ETRO-01911   C57BL/6J 2023-03-03
# 2354  TRO-028339        ID_096  ETRO-01911   C57BL/6J 2023-03-03
# 2355  TRO-028342        ID_096  ETRO-01911   C57BL/6J 2023-03-03
# 2356  TRO-028343        ID_096  ETRO-01911   C57BL/6J 2023-03-03
#
#                                       Experiment Group           Group_info  \
# 0                             Candida/Propionate    1A  Propionate / 2*10^5
# 1                             Candida/Propionate    1A  Propionate / 2*10^5
# 2                             Candida/Propionate    1A  Propionate / 2*10^5
# 3                             Candida/Propionate    1A  Propionate / 2*10^5
# 4                             Candida/Propionate    1A  Propionate / 2*10^5
# ...                                          ...   ...                  ...
# 2352  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
# 2353  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
# 2354  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
# 2355  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
# 2356  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
#
#      H0             Pre_traitment  ... survival_0.07 time_0.06 survival_0.06  \
# 0     1                propionate  ...             1       1.5             1
# 1     1                propionate  ...             1       1.5             1
# 2     1                propionate  ...             1       2.5             1
# 3     1                propionate  ...             1       1.5             1
# 4     1                propionate  ...             1       1.5             1
# ...  ..                       ...  ...           ...       ...           ...
# 2352  1  training/cross-fostering  ...             1       1.5             1
# 2353  1  training/cross-fostering  ...             1       2.5             1
# 2354  1  training/cross-fostering  ...             1       5.5             1
# 2355  1  training/cross-fostering  ...             0       8.0             0
# 2356  1  training/cross-fostering  ...             1       2.5             1
#
#      time_0.05 survival_0.05 time_original  survival_original  \
# 0          1.5             1           9.0               Dead
# 1          1.5             1           9.0               Dead
# 2          2.5             1           9.0               Dead
# 3          1.5             1           6.0               Dead
# 4          1.5             1           7.0               Dead
# ...        ...           ...           ...                ...
# 2352       1.5             1           5.0               Dead
# 2353       2.5             1           4.0               Dead
# 2354       5.5             1           6.0               Dead
# 2355       8.0             0           8.0              Alive
# 2356       2.5             1           5.0               Dead
#
#       max_loss_weight_percentage exp sub_exp
# 0                       0.629181   1       A
# 1                       0.660748   1       A
# 2                       0.639184   1       A
# 3                       0.664051   1       A
# 4                       0.707420   1       A
# ...                          ...  ..     ...
# 2352                    0.761733   3      no
# 2353                    0.865900   3      no
# 2354                    0.926829   3      no
# 2355                    0.996350   3      no
# 2356                    0.889706   3      no
#
# [2357 rows x 88 columns]

# %%
df_under_30 = df[df['max_loss_weight_percentage']<0.7]
df_under_30.groupby('Infection')['Mouse_ID'].count()
# Out:
# Infection
# C. albicans      64
# H1N1             68
# Listeria          8
# S. pneumoniae     2
# Name: Mouse_ID, dtype: int64

# %%
len(df_under_30)
# Out:
# 142

# %%
df_under_30_survivor = df_under_30[df_under_30['survival_original']=='Alive']
df_under_30_survivor.groupby('Infection')['Mouse_ID'].count()
# Out:
# Infection
# C. albicans      16
# H1N1             17
# Listeria          5
# S. pneumoniae     1
# Name: Mouse_ID, dtype: int64

# %%
len(df_under_30_survivor)
# Out:
# 39

# %% [markdown]
# ## Number of Mice per ethical autorization (included in analysis)

# %%
df_auth1 = df[df['Date'] < datetime(2018,5,1)] # 2 were already excluded from the data
df_auth2 = df[df['Date']>= datetime(2018,5,1)] # 41 were already excluded from the data
df_auth2.head()
# Out:
#       Mouse_ID ID_Experiment        Cage    Strain       Date  \
# 777  TRO-18099        ID_029  ETRO-00940  C57BL/6J 2018-05-28
# 778  TRO-18100        ID_029  ETRO-00940  C57BL/6J 2018-05-28
# 779  TRO-18101        ID_029  ETRO-00940  C57BL/6J 2018-05-28
# 780  TRO-18102        ID_029  ETRO-00940  C57BL/6J 2018-05-28
# 781  TRO-18103        ID_029  ETRO-00940  C57BL/6J 2018-05-28
#
#                        Experiment Group                          Group_info  \
# 777  Listeria/Clodronate/Training     1  Zymosam + PBS liposome + Listeria
# 778  Listeria/Clodronate/Training     1  Zymosam + PBS liposome + Listeria
# 779  Listeria/Clodronate/Training     1  Zymosam + PBS liposome + Listeria
# 780  Listeria/Clodronate/Training     1  Zymosam + PBS liposome + Listeria
# 781  Listeria/Clodronate/Training     1  Zymosam + PBS liposome + Listeria
#
#      H0     Pre_traitment  ... survival_0.07 time_0.06 survival_0.06  \
# 777  -1  training/zymosan  ...             0       6.5             1
# 778  -1  training/zymosan  ...             1       2.5             1
# 779  -1  training/zymosan  ...             0       8.0             0
# 780  -1  training/zymosan  ...             1       2.5             1
# 781  -1  training/zymosan  ...             0       6.5             1
#
#     time_0.05 survival_0.05 time_original  survival_original  \
# 777       2.5             1           8.0              Alive
# 778       2.5             1           8.0              Alive
# 779       8.0             0           8.0              Alive
# 780       2.5             1           8.0              Alive
# 781       2.5             1           8.0              Alive
#
#      max_loss_weight_percentage exp sub_exp
# 777                    0.935644   1      no
# 778                    0.876289   1      no
# 779                    0.973404   1      no
# 780                    0.893023   1      no
# 781                    0.935135   1      no
#
# [5 rows x 88 columns]

# %% [markdown]
# ### authorization 1, from 2013-2018

# %%
df_auth1.groupby(['Infection'])['Mouse_ID'].count()
# Out:
# Infection
# C. albicans      252
# H1N1              63
# Listeria         263
# S. pneumoniae    211
# Name: Mouse_ID, dtype: int64

# %%
#total
df_auth1.groupby(['Infection'])['Mouse_ID'].count().sum()
# Out:
# 789

# %% [markdown]
# ### authorization 2, from 2018-2023

# %%
df_auth2.groupby(['Infection'])['Mouse_ID'].count()
# Out:
# Infection
# H1N1             273
# Listeria         785
# S. pneumoniae    510
# Name: Mouse_ID, dtype: int64

# %%
#total
df_auth2.groupby(['Infection'])['Mouse_ID'].count().sum()
# Out:
# 1568

# %% [markdown]
# ## Average maximum weight loss for non survivor mice

# %%
df_dead = df[df['survival_original']=='Dead']
df_dead.groupby('Infection').max_loss_weight_percentage.mean()*100
# Out:
# Infection
# C. albicans      72.624314
# H1N1             75.015886
# Listeria         81.643642
# S. pneumoniae    84.984221
# Name: max_loss_weight_percentage, dtype: float64

# %%
df_dead.max_loss_weight_percentage.mean()*100
# Out:
# 81.31940006860864
