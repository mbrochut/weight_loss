# %% [markdown]
# # Statistical Analysis
# ## Import packages and load data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from scipy.stats import chisquare
import ast

# %%
df = pd.read_excel("./data/df_for_analysis.xlsx",index_col=0)

# %% [markdown]
# ### Table general information

# %%
start_date = datetime(2013,1,1)
end_date = datetime.now()

#Select data between two dates
mask_date = (df['Date'] > start_date) & (df['Date'] <= end_date)
df = df.loc[mask_date]

# %%
df
# Out:
#         Mouse_ID ID_Experiment        Cage     Strain       Date  \
# 0      TRO-05432        ID_001           A  BALB/cByJ 2014-06-05
# 1      TRO-05433        ID_001           A  BALB/cByJ 2014-06-05
# 2      TRO-05434        ID_001           A  BALB/cByJ 2014-06-05
# 3      TRO-05435        ID_001           A  BALB/cByJ 2014-06-05
# 4      TRO-05456        ID_001           B  BALB/cByJ 2014-06-05
# ...          ...           ...         ...        ...        ...
# 2352  TRO-028337        ID_096  ETRO-01911   C57BL/6J 2023-03-03
# 2353  TRO-028338        ID_096  ETRO-01911   C57BL/6J 2023-03-03
# 2354  TRO-028339        ID_096  ETRO-01911   C57BL/6J 2023-03-03
# 2355  TRO-028342        ID_096  ETRO-01911   C57BL/6J 2023-03-03
# 2356  TRO-028343        ID_096  ETRO-01911   C57BL/6J 2023-03-03
#
#                                       Experiment Group           Group_info  \
# 0                             Candida/Propionate    1A  Propionate / 2*10^5
# 1                             Candida/Propionate    1A  Propionate / 2*10^5
# 2                             Candida/Propionate    1A  Propionate / 2*10^5
# 3                             Candida/Propionate    1A  Propionate / 2*10^5
# 4                             Candida/Propionate    1A  Propionate / 2*10^5
# ...                                          ...   ...                  ...
# 2352  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
# 2353  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
# 2354  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
# 2355  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
# 2356  Pneumococcus/Training/Cross-fostering/male     3             D. Zy-Zy
#
#      H0             Pre_traitment  ... survival_0.07 time_0.06 survival_0.06  \
# 0     1                propionate  ...             1       1.5             1
# 1     1                propionate  ...             1       1.5             1
# 2     1                propionate  ...             1       2.5             1
# 3     1                propionate  ...             1       1.5             1
# 4     1                propionate  ...             1       1.5             1
# ...  ..                       ...  ...           ...       ...           ...
# 2352  1  training/cross-fostering  ...             1       1.5             1
# 2353  1  training/cross-fostering  ...             1       2.5             1
# 2354  1  training/cross-fostering  ...             1       5.5             1
# 2355  1  training/cross-fostering  ...             0      11.0             0
# 2356  1  training/cross-fostering  ...             1       2.5             1
#
#      time_0.05 survival_0.05 time_original  survival_original  \
# 0          1.5             1           9.0                  1
# 1          1.5             1           9.0                  1
# 2          2.5             1           9.0                  1
# 3          1.5             1           6.0                  1
# 4          1.5             1           7.0                  1
# ...        ...           ...           ...                ...
# 2352       1.5             1           5.0                  1
# 2353       2.5             1           4.0                  1
# 2354       5.5             1           6.0                  1
# 2355      11.0             0          11.0                  0
# 2356       2.5             1           5.0                  1
#
#       max_loss_weight_percentage exp sub_exp
# 0                       0.629181   1       A
# 1                       0.660748   1       A
# 2                       0.639184   1       A
# 3                       0.664051   1       A
# 4                       0.707420   1       A
# ...                          ...  ..     ...
# 2352                    0.761733   3      no
# 2353                    0.865900   3      no
# 2354                    0.926829   3      no
# 2355                    0.996350   3      no
# 2356                    0.889706   3      no
#
# [2357 rows x 89 columns]

# %%
#change name of dead and alive for result formatting
df['survival_original'] = df['survival_original'].replace({1:'Dead',0:'Alive'})

# %%
#RESULT: N_Experiment; N_Mice
group_by_infection = df.groupby(['Infection'])
n_unique = group_by_infection.nunique()
n_unique_infos = n_unique.loc[:,:'ID_Experiment']
n_unique_infos = n_unique_infos.rename(columns={'ID_Experiment':'N_Experiment','Mouse_ID':'N_Mice'})

#RESULT: Alive; Dead; Alive_in_%
dead_alive = group_by_infection['survival_original'].value_counts().sort_index(ascending=False).unstack()

# %%
result = pd.concat([n_unique_infos,dead_alive],axis=1)
result
# Out:
#                N_Mice  N_Experiment  Alive  Dead
# Infection
# C. albicans       252             6    156    96
# H1N1              336            19    184   152
# Listeria         1048            39    460   588
# S. pneumoniae     721            32    308   413

# %%
# Create a dictionary with the sum of each column
total_sum = result.sum()

# Create a DataFrame from the sum with the index name 'Total'
total_df = pd.DataFrame(total_sum).T
total_df.index = ['Total']
total_df.index.name = 'Infection'
total_df
# Out:
#            N_Mice  N_Experiment  Alive  Dead
# Infection
# Total        2357            96   1108  1249

# %%
general_info = pd.concat([result,total_df],axis=0)

# %%
general_info['mortality'] = round(general_info['Dead']/(general_info['Alive']+general_info['Dead'])*100,1)
general_info
# Out:
#                N_Mice  N_Experiment  Alive  Dead  mortality
# Infection
# C. albicans       252             6    156    96       38.1
# H1N1              336            19    184   152       45.2
# Listeria         1048            39    460   588       56.1
# S. pneumoniae     721            32    308   413       57.3
# Total            2357            96   1108  1249       53.0

# %% [markdown]
# ### Survival percentage

# %%
data = df.loc[:,['Infection','survival_original','survival_0.3','survival_0.25','survival_0.2','survival_0.15','survival_0.1']]
data = data.replace({0:'Alive',1:'Dead'})
data
# Out:
#           Infection survival_original survival_0.3 survival_0.25 survival_0.2  \
# 0       C. albicans              Dead         Dead          Dead         Dead
# 1       C. albicans              Dead         Dead          Dead         Dead
# 2       C. albicans              Dead         Dead          Dead         Dead
# 3       C. albicans              Dead         Dead          Dead         Dead
# 4       C. albicans              Dead         Dead          Dead         Dead
# ...             ...               ...          ...           ...          ...
# 2352  S. pneumoniae              Dead         Dead          Dead         Dead
# 2353  S. pneumoniae              Dead         Dead          Dead         Dead
# 2354  S. pneumoniae              Dead         Dead          Dead         Dead
# 2355  S. pneumoniae             Alive        Alive         Alive        Alive
# 2356  S. pneumoniae              Dead         Dead          Dead         Dead
#
#      survival_0.15 survival_0.1
# 0             Dead         Dead
# 1             Dead         Dead
# 2             Dead         Dead
# 3             Dead         Dead
# 4             Dead         Dead
# ...            ...          ...
# 2352          Dead         Dead
# 2353          Dead         Dead
# 2354          Dead         Dead
# 2355         Alive        Alive
# 2356          Dead         Dead
#
# [2357 rows x 7 columns]

# %%
survival = data.melt(id_vars=["Infection"],value_name="survival",var_name="threshold")
survival = survival.groupby('Infection').value_counts().reset_index().rename(columns={0:"number_of_mice"})
survival
# Out:
#         Infection          threshold survival  number_of_mice
# 0     C. albicans       survival_0.1     Dead             220
# 1     C. albicans      survival_0.15     Dead             189
# 2     C. albicans  survival_original    Alive             156
# 3     C. albicans       survival_0.2     Dead             151
# 4     C. albicans       survival_0.3    Alive             145
# 5     C. albicans      survival_0.25    Alive             130
# 6     C. albicans      survival_0.25     Dead             122
# 7     C. albicans       survival_0.3     Dead             107
# 8     C. albicans       survival_0.2    Alive             101
# 9     C. albicans  survival_original     Dead              96
# 10    C. albicans      survival_0.15    Alive              63
# 11    C. albicans       survival_0.1    Alive              32
# 12           H1N1       survival_0.1     Dead             288
# 13           H1N1      survival_0.15     Dead             260
# 14           H1N1       survival_0.2     Dead             221
# 15           H1N1      survival_0.25     Dead             195
# 16           H1N1  survival_original    Alive             184
# 17           H1N1       survival_0.3     Dead             170
# 18           H1N1       survival_0.3    Alive             166
# 19           H1N1  survival_original     Dead             152
# 20           H1N1      survival_0.25    Alive             141
# 21           H1N1       survival_0.2    Alive             115
# 22           H1N1      survival_0.15    Alive              76
# 23           H1N1       survival_0.1    Alive              48
# 24       Listeria       survival_0.1     Dead             795
# 25       Listeria      survival_0.15     Dead             721
# 26       Listeria       survival_0.2     Dead             639
# 27       Listeria      survival_0.25     Dead             607
# 28       Listeria       survival_0.3     Dead             592
# 29       Listeria  survival_original     Dead             588
# 30       Listeria  survival_original    Alive             460
# 31       Listeria       survival_0.3    Alive             456
# 32       Listeria      survival_0.25    Alive             441
# 33       Listeria       survival_0.2    Alive             409
# 34       Listeria      survival_0.15    Alive             327
# 35       Listeria       survival_0.1    Alive             253
# 36  S. pneumoniae       survival_0.1     Dead             447
# 37  S. pneumoniae      survival_0.15     Dead             423
# 38  S. pneumoniae       survival_0.2     Dead             418
# 39  S. pneumoniae      survival_0.25     Dead             414
# 40  S. pneumoniae  survival_original     Dead             413
# 41  S. pneumoniae       survival_0.3     Dead             413
# 42  S. pneumoniae       survival_0.3    Alive             308
# 43  S. pneumoniae  survival_original    Alive             308
# 44  S. pneumoniae      survival_0.25    Alive             307
# 45  S. pneumoniae       survival_0.2    Alive             303
# 46  S. pneumoniae      survival_0.15    Alive             298
# 47  S. pneumoniae       survival_0.1    Alive             274

# %%
# Pivot the table to have 'Infection' as columns and calculate the ratio
pivot_table = survival.pivot(index=['Infection',"threshold"], columns='survival', values='number_of_mice')
pivot_table['Ratio'] = pivot_table['Dead'] / (pivot_table['Dead'] + pivot_table['Alive'])
pivot_table = pivot_table.reset_index(level=1)
pivot_table['supplementary_death'] = pivot_table.groupby('Infection').apply(lambda x: x['Dead'] - x[x['threshold']=="survival_original"]['Dead']).values
pivot_table
# Out:
# survival               threshold  Alive  Dead     Ratio  supplementary_death
# Infection
# C. albicans         survival_0.1     32   220  0.873016                  124
# C. albicans        survival_0.15     63   189  0.750000                   93
# C. albicans         survival_0.2    101   151  0.599206                   55
# C. albicans        survival_0.25    130   122  0.484127                   26
# C. albicans         survival_0.3    145   107  0.424603                   11
# C. albicans    survival_original    156    96  0.380952                    0
# H1N1                survival_0.1     48   288  0.857143                  136
# H1N1               survival_0.15     76   260  0.773810                  108
# H1N1                survival_0.2    115   221  0.657738                   69
# H1N1               survival_0.25    141   195  0.580357                   43
# H1N1                survival_0.3    166   170  0.505952                   18
# H1N1           survival_original    184   152  0.452381                    0
# Listeria            survival_0.1    253   795  0.758588                  207
# Listeria           survival_0.15    327   721  0.687977                  133
# Listeria            survival_0.2    409   639  0.609733                   51
# Listeria           survival_0.25    441   607  0.579198                   19
# Listeria            survival_0.3    456   592  0.564885                    4
# Listeria       survival_original    460   588  0.561069                    0
# S. pneumoniae       survival_0.1    274   447  0.619972                   34
# S. pneumoniae      survival_0.15    298   423  0.586685                   10
# S. pneumoniae       survival_0.2    303   418  0.579750                    5
# S. pneumoniae      survival_0.25    307   414  0.574202                    1
# S. pneumoniae       survival_0.3    308   413  0.572816                    0
# S. pneumoniae  survival_original    308   413  0.572816                    0

# %% [markdown]
# ### Test of Chi2

# %%
def chi_square_in_lambda_function(x):
    observed = x[x['threshold']=='survival_original'][['Dead','Alive']].values.tolist()[0]
    result = []
    for index, rows in x.iterrows():
        data = rows[['Dead','Alive']]
        chi2, p = chisquare(observed,data)
        result += [p]
    x.index
    return pd.Series(result,x.index.values)

# %%
pivot_table = pivot_table.reset_index()

# %%
pivot_table
# Out:
# survival      Infection          threshold  Alive  Dead     Ratio  \
# 0           C. albicans       survival_0.1     32   220  0.873016
# 1           C. albicans      survival_0.15     63   189  0.750000
# 2           C. albicans       survival_0.2    101   151  0.599206
# 3           C. albicans      survival_0.25    130   122  0.484127
# 4           C. albicans       survival_0.3    145   107  0.424603
# 5           C. albicans  survival_original    156    96  0.380952
# 6                  H1N1       survival_0.1     48   288  0.857143
# 7                  H1N1      survival_0.15     76   260  0.773810
# 8                  H1N1       survival_0.2    115   221  0.657738
# 9                  H1N1      survival_0.25    141   195  0.580357
# 10                 H1N1       survival_0.3    166   170  0.505952
# 11                 H1N1  survival_original    184   152  0.452381
# 12             Listeria       survival_0.1    253   795  0.758588
# 13             Listeria      survival_0.15    327   721  0.687977
# 14             Listeria       survival_0.2    409   639  0.609733
# 15             Listeria      survival_0.25    441   607  0.579198
# 16             Listeria       survival_0.3    456   592  0.564885
# 17             Listeria  survival_original    460   588  0.561069
# 18        S. pneumoniae       survival_0.1    274   447  0.619972
# 19        S. pneumoniae      survival_0.15    298   423  0.586685
# 20        S. pneumoniae       survival_0.2    303   418  0.579750
# 21        S. pneumoniae      survival_0.25    307   414  0.574202
# 22        S. pneumoniae       survival_0.3    308   413  0.572816
# 23        S. pneumoniae  survival_original    308   413  0.572816
#
# survival  supplementary_death
# 0                         124
# 1                          93
# 2                          55
# 3                          26
# 4                          11
# 5                           0
# 6                         136
# 7                         108
# 8                          69
# 9                          43
# 10                         18
# 11                          0
# 12                        207
# 13                        133
# 14                         51
# 15                         19
# 16                          4
# 17                          0
# 18                         34
# 19                         10
# 20                          5
# 21                          1
# 22                          0
# 23                          0

# %%
chi_result = pivot_table.groupby("Infection").apply(lambda x: chi_square_in_lambda_function(x))
pivot_table["chi2"] = chi_result.values
pivot_table
# Out:
# survival      Infection          threshold  Alive  Dead     Ratio  \
# 0           C. albicans       survival_0.1     32   220  0.873016
# 1           C. albicans      survival_0.15     63   189  0.750000
# 2           C. albicans       survival_0.2    101   151  0.599206
# 3           C. albicans      survival_0.25    130   122  0.484127
# 4           C. albicans       survival_0.3    145   107  0.424603
# 5           C. albicans  survival_original    156    96  0.380952
# 6                  H1N1       survival_0.1     48   288  0.857143
# 7                  H1N1      survival_0.15     76   260  0.773810
# 8                  H1N1       survival_0.2    115   221  0.657738
# 9                  H1N1      survival_0.25    141   195  0.580357
# 10                 H1N1       survival_0.3    166   170  0.505952
# 11                 H1N1  survival_original    184   152  0.452381
# 12             Listeria       survival_0.1    253   795  0.758588
# 13             Listeria      survival_0.15    327   721  0.687977
# 14             Listeria       survival_0.2    409   639  0.609733
# 15             Listeria      survival_0.25    441   607  0.579198
# 16             Listeria       survival_0.3    456   592  0.564885
# 17             Listeria  survival_original    460   588  0.561069
# 18        S. pneumoniae       survival_0.1    274   447  0.619972
# 19        S. pneumoniae      survival_0.15    298   423  0.586685
# 20        S. pneumoniae       survival_0.2    303   418  0.579750
# 21        S. pneumoniae      survival_0.25    307   414  0.574202
# 22        S. pneumoniae       survival_0.3    308   413  0.572816
# 23        S. pneumoniae  survival_original    308   413  0.572816
#
# survival  supplementary_death           chi2
# 0                         124  1.035027e-121
# 1                          93   1.047205e-41
# 2                          55   1.550358e-12
# 3                          26   1.047886e-03
# 4                          11   1.609451e-01
# 5                           0   1.000000e+00
# 6                         136  9.012372e-100
# 7                         108   4.820932e-45
# 8                          69   2.127774e-15
# 9                          43   1.999496e-06
# 10                         18   4.951847e-02
# 11                          0   1.000000e+00
# 12                        207   1.757665e-50
# 13                        133   7.494944e-19
# 14                         51   1.239958e-03
# 15                         19   2.345057e-01
# 16                          4   8.031842e-01
# 17                          0   1.000000e+00
# 18                         34   9.089746e-03
# 19                         10   4.494743e-01
# 20                          5   7.059885e-01
# 21                          1   9.399618e-01
# 22                          0   1.000000e+00
# 23                          0   1.000000e+00
